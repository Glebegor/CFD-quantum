# %% [markdown]
# # CFD by QLBM
#
# ## Goal
# - Show d1q3 computing
# - coded $$ fi(x) $$ in quantum state
# - find distribution back
# - computation of p, u, pe
# - difference between streaming and classical np.roll
#
# At the start we will use state vector and after normal QPU and shots

# %%
# !pip install pandas
# !pip install numpy
# !pip install sympy
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn
# !pip install qiskit
# !pip install qiskit-aer
# !pip install qiskit-ibmq-provider
# !pip install qiskit-ibm-runtime
# !pip install qiskit-ibm-catalog
# %matplotlib inline
# Out:
# ...
#   Using cached qiskit_ibmq_provider-0.20.2-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached qiskit_terra-0.46.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (13 kB)
# ...
#   Using cached requests_ntlm-1.1.0-py2.py3-none-any.whl.metadata (938 bytes)
# ...
#   Using cached numpy-1.23.5.tar.gz (10.7 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/glebegor/Programming/studing/qiskit-summer/Lab1/venv/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 109, in _run_wrapper
#     status = _inner_run()
#              ^^^^^^^^^^^^
#   File "/Users/glebegor/Programming/studing/qiskit-summer/Lab1/venv/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 102, in _inner_run
#     return self.run(options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# Count of qubits: 5<br>
# 3 position qubits<br>
# 2 direction qubits<br>
#
# ## Registers
# $$ |d>|x> $$
#
# $$ |00> |010> $$ - relax state x=2<br>
# $$ |01> |010> $$ - move to right x=2<br>
# $$ |10> |010> $$ - move to left x=2<br>
# $$ |11> |010> $$ - empty state<br>
#
#
# ## Velocities
# $$ c0=0, c1=1, c2=-1 $$
#
# ## Weights
# $$ w0=2/3, w1=w2=1/6 $$
#
# ## Macrosizes
# $$ p(x)=f0(x)+f1(x)+f2(x) $$

# %%
QLBM
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 QLBM
#
# NameError: name 'QLBM' is not defined
